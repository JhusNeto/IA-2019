# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sb

# %matplotlib inline

# %% [markdown]
# # IMPORTANDO DADOS

# %%
df = pd.read_csv('https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv')

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# 5                  5.4               3.9                1.7               0.4
# 6                  4.6               3.4                1.4               0.3
# 7                  5.0               3.4                1.5               0.2
# 8                  4.4               2.9                1.4               0.2
# 9                  4.9               3.1                1.5               0.1
# 10                 5.4               3.7                1.5               0.2
# ...

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df['Área Sépala'] = df['sepal length (cm)'] * df['sepal width (cm)']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sepal length (cm)'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-c21ecdd5ed5f> in <module>()
# ...

# %%
df['Área Pétala'] = df['petal_length'] * df['petal_width']

# %%
df['Área Sépala'] = df['sepal_length'] * df['sepal_width']

# %%
df['Soma Áreas'] = df['Área Pétala'] * df['Área Sépala']

# %%
sb.pairplot(df, hue='Área Sépala')

# %%
df['Área Sépala'].idxmax()
# Out:
# 131

# %%
X[131]
# Out:
# array([  7.9 ,   3.8 ,   6.4 ,   2.  ,  30.02,  12.8 ,  42.82])

# %%
df['Área Pétala'].idxmax()
# Out:
# 118

# %%
X[118]
# Out:
# array([  7.7 ,   2.6 ,   6.9 ,   2.3 ,  20.02,  15.87,  35.89])

# %%
df['Soma Áreas'].idxmax()
# Out:
# 117

# %%
X[117]
# Out:
# array([  7.7 ,   3.8 ,   6.7 ,   2.2 ,  29.26,  14.74,  44.  ])

# %%
df_dropado = df.drop(df.index>30)

# %%
df_dropado
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# 5                  5.4               3.9                1.7               0.4
# 6                  4.6               3.4                1.4               0.3
# 7                  5.0               3.4                1.5               0.2
# 8                  4.4               2.9                1.4               0.2
# 9                  4.9               3.1                1.5               0.1
# 10                 5.4               3.7                1.5               0.2
# 11                 4.8               3.4                1.6               0.2
# 12                 4.8               3.0                1.4               0.1
# ...

# %%
sb.pairplot(df, hue='Área Pétala')

# %%
sb.pairplot(df, hue='Soma Áreas')

# %%
X = np.array(df.drop('target', axis=1))

# %%
X
# Out:
# array([[  5.1 ,   3.5 ,   1.4 , ...,  17.85,   0.28,  18.13],
#        [  4.9 ,   3.  ,   1.4 , ...,  14.7 ,   0.28,  14.98],
#        [  4.7 ,   3.2 ,   1.3 , ...,  15.04,   0.26,  15.3 ],
#        ...,
#        [  6.5 ,   3.  ,   5.2 , ...,  19.5 ,  10.4 ,  29.9 ],
#        [  6.2 ,   3.4 ,   5.4 , ...,  21.08,  12.42,  33.5 ],
#        [  5.9 ,   3.  ,   5.1 , ...,  17.7 ,   9.18,  26.88]])

# %%
y = np.array(df.target)

# %%
y
# Out:
# array(['SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA',
#        'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA',
#        'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA',
#        'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA',
#        'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA',
#        'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA',
#        'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA',
#        'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA', 'SETOSA',
#        'SETOSA', 'SETOSA', 'VERSICOLOR', 'VERSICOLOR', 'VERSICOLOR',
#        'VERSICOLOR', 'VERSICOLOR', 'VERSICOLOR', 'VERSICOLOR',
#        'VERSICOLOR', 'VERSICOLOR', 'VERSICOLOR', 'VERSICOLOR',
#        'VERSICOLOR', 'VERSICOLOR', 'VERSICOLOR', 'VERSICOLOR',
#        'VERSICOLOR', 'VERSICOLOR', 'VERSICOLOR', 'VERSICOLOR',
#        'VERSICOLOR', 'VERSICOLOR', 'VERSICOLOR', 'VERSICOLOR',
# ...

# %% [markdown]
# # TREINAMENTO

# %%
from sklearn import tree

# %%
clf = tree.DecisionTreeClassifier()

# %%
clf.fit(X,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %% [markdown]
# # PREDIÇÃO

# %% [markdown]
# # sex, age, social_class

# %%
clf.predict([ 7.9 ,   3.8 ,   6.4 ,   2.  ,  30.02,  12.8 ,  42.82])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# array(['VIRGINICA'], dtype=object)

# %%
clf.predict([7.7 ,   2.6 ,   6.9 ,   2.3 ,  20.02,  15.87,  35.89])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# array(['VIRGINICA'], dtype=object)

# %%
clf.predict_proba([7.7 ,   3.8 ,   6.7 ,   2.2 ,  29.26,  14.74,  44. ])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# array([[ 0.,  0.,  1.]])

# %%
import pickle

# %%
filename = 'titanic.plk'

pickle.dump(clf, open(filename, 'wb'))

# %% [markdown]
# # CARREGANDO O MODELO

# %%
clf_loaded = pickle.load(open(filename, 'rb'))

# %%
clf_loaded.predict([[1,42,2],
             [0,38,2],
             [0,14,2],
             [1,19,2]])
# Out:
# array(['no', 'no', 'yes', 'no'], dtype=object)
